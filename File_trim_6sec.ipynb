# %%
import pandas as pd
no_of_users=20
no_of_video=10
for i in range(no_of_users):  
        if(i%1 == 0):
            if i < 10:
                name = '%0*d' % (2,i+1)
            else:
                name = i+1
        for j in range(no_of_video):
            
            fname = "DataSet/DataSet_one_second/S"+str(name)+"_1/S"+str(name)+"_video"+str(j+1)+".csv" 
            print(fname)
            df = pd.read_csv(fname)
            df.drop(df.head(3000).index, inplace=True)
            df.drop(df.tail(3000).index, inplace=True)
            df.to_csv(fname)

# %%
from sklearn.decomposition import PCA
import numpy as np
import pylab as pyl
import matplotlib.pyplot as plt
import pandas as pd
import os
import csv
import pywt, numpy
import itertools 



list_f=[]
no_of_users=20
no_of_video=10

for i in range(no_of_users):   #no_of_users
        print(".............................",i)
        if(i%1 == 0 ):
            if i < 10:
                name = '%0*d' % (2,i+1)
            else:
                name = i+1
        for j in range(no_of_video):
            
            fname = "DataSet/DataSet_one_second/S"+str(name)+"_1/S"+str(name)+"_video"+str(j+1)+".csv" 
            fname = "DataSet/DataSet_one_second1/S"+str(name)+"_1/S"+str(name)+"_video"+str(j+1)+".csv" 
            print(fname)
            print(fname1)
            df1 = pd.read_csv(fname)
            df=df1['RAW']
            #print(type(df))
            x = df.values.tolist()
            list_f.append(x)
            #df.values
            print(len(x))
            n = 512
  
            # using list comprehension 
            final = [x[i * n:(i + 1) * n] for i in range((len(x) + n - 1) // n )]  
            print (len(final))
            final = final[:-1]
            np.savetxt(fname1, final, delimiter=",")

# %%
from sklearn.decomposition import PCA
import numpy as np
import pylab as pyl
import matplotlib.pyplot as plt
import pandas as pd
import os
import csv
import pywt, numpy
import itertools 



list_f=[]
no_of_users=20
no_of_video=10

for i in range(no_of_users):   #no_of_users
        print(".............................",i)
        
        if(i%1 == 0 ):
            if i < 10:
                name = '%0*d' % (2,i+1)
            else:
                name = i+1
        for j in range(no_of_video):
            
            fname = "DataSet/DataSet_two_second/S"+str(name)+"_2/S"+str(name)+"_video"+str(j+1)+".csv" 
            fname = "DataSet/DataSet_two_second2/S"+str(name)+"_2/S"+str(name)+"_video"+str(j+1)+".csv" 
            print(fname)
            print(fname1)
            df1 = pd.read_csv(fname)
            df=df1['RAW']
            #print(type(df))
            x = df.values.tolist()
            list_f.append(x)
            #df.values
            print(len(x))
            n = 1024
  
            # using list comprehension 
            final = [x[i * n:(i + 1) * n] for i in range((len(x) + n - 1) // n )]  
            print (len(final))
            final = final[:-1]
            np.savetxt(fname1, final, delimiter=",")

# %%
from sklearn.decomposition import PCA
import numpy as np
import pylab as pyl
import matplotlib.pyplot as plt
import pandas as pd
import os
import csv
import pywt, numpy
import itertools 



list_f=[]
no_of_users=20
no_of_video=10

for i in range(no_of_users):   #no_of_users
        print(".............................",i)
       
        if(i%1 == 0 ):
            if i < 10:
                name = '%0*d' % (2,i+1)
            else:
                name = i+1
        for j in range(no_of_video):
            
            fname = "DataSet/DataSet_three_second/S"+str(name)+"_3/S"+str(name)+"_video"+str(j+1)+".csv" 
            fname = "DataSet/DataSet_three_second3/S"+str(name)+"_3/S"+str(name)+"_video"+str(j+1)+".csv" 
            print(fname)
            print(fname1)
            df1 = pd.read_csv(fname)
            df=df1['RAW']
            #print(type(df))
            x = df.values.tolist()
            list_f.append(x)
            #df.values
            print(len(x))
            n = 1536
  
            # using list comprehension 
            final = [x[i * n:(i + 1) * n] for i in range((len(x) + n - 1) // n )]  
            print (len(final))
            final = final[:-1]
            np.savetxt(fname1, final, delimiter=",")
